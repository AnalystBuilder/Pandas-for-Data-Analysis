# %% [markdown]
# # Reshaping and Pivoting Indexes

# %%
import pandas as pd

# %%
df = pd.read_excel(r'C:\Users\alexf\OneDrive\Documents\Tutorials\Pandas Folder\Indexing Lesson\tech_price.xlsx'
                  , header = [0,1], index_col = [0,1])

pd.set_option('display.max.rows',1350)
pd.set_option('display.max.columns',15)

# %%
df
# Out:
#                    USD                 EUR
# company           open high low close open high low close
# 2023-01-01 Apple    89   26  68    69   37   56  11    25
#            Google   66   71  26    83   96   68  91    11
#            Amazon   12   43  97    75   25   25  90    43
# 2023-01-02 Apple    54   49  77    49   68   44  85    68
#            Google   84   92  55    90   51   50  59    68
#            Amazon   41   86  13    19   41   36  50    26
# 2023-01-03 Apple    67   47  46    70   41   62  72    49
#            Google   60   70  54    71   78   47  12    57
#            Amazon   71   15  47    53   86   44  68    33
# 2023-01-04 Apple    56   50  54    83   59   36  45    19
#            Google   36   77  27    94   62   13  66    90
#            Amazon   64   97  64    56   48   57  45    50
# 2023-01-05 Apple    34   45  60    84   24   49  63    54
#            Google   69   92  14    63   21   85  80    87
# ...

# %%
df2 = df.stack()
df2
# Out:
#                            EUR  USD
#                   company
# 2023-01-01 Apple  close     25   69
#                   high      56   26
#                   low       11   68
#                   open      37   89
#            Google close     11   83
#                   high      68   71
#                   low       91   26
#                   open      96   66
#            Amazon close     43   75
#                   high      25   43
#                   low       90   97
#                   open      25   12
# 2023-01-02 Apple  close     68   49
#                   high      44   49
#                   low       85   77
#                   open      68   54
#            Google close     68   90
#                   high      50   92
#                   low       59   55
#                   open      51   84
#            Amazon close     26   19
#                   high      36   86
#                   low       50   13
#                   open      41   41
# ...

# %%
df2.unstack()
# Out:
#                     EUR                 USD
# company           close high low open close high low open
# 2023-01-01 Amazon    43   25  90   25    75   43  97   12
#            Apple     25   56  11   37    69   26  68   89
#            Google    11   68  91   96    83   71  26   66
# 2023-01-02 Amazon    26   36  50   41    19   86  13   41
#            Apple     68   44  85   68    49   49  77   54
#            Google    68   50  59   51    90   92  55   84
# 2023-01-03 Amazon    33   44  68   86    53   15  47   71
#            Apple     49   62  72   41    70   47  46   67
#            Google    57   47  12   78    71   70  54   60
# 2023-01-04 Amazon    50   57  45   48    56   97  64   64
#            Apple     19   36  45   59    83   50  54   56
#            Google    90   13  66   62    94   77  27   36
# 2023-01-05 Amazon    30   63  95   91    43   75  27   63
#            Apple     54   49  63   24    84   45  60   34
# ...

# %%
df_world = pd.read_csv(r'C:\Users\alexf\OneDrive\Documents\Tutorials\Pandas Folder\Indexing Lesson\WorldContinents.csv'
                      , encoding = 'ISO-8859-1')

pd.set_option('display.max.rows',1350)
pd.set_option('display.max.columns',15)

# %%
df_world
# Out:
#     continent                 sub_region  \
# 0        Asia              Southern Asia
# 1      Europe            Northern Europe
# 2      Europe            Southern Europe
# 3      Africa            Northern Africa
# 4     Oceania                  Polynesia
# 5      Europe            Southern Europe
# 6      Africa              Middle Africa
# 7    Americas                  Caribbean
# 8    Americas                  Caribbean
# 9    Americas              South America
# 10       Asia               Western Asia
# 11   Americas                  Caribbean
# 12    Oceania  Australia and New Zealand
# 13     Europe             Western Europe
# 14       Asia               Western Asia
# 15   Americas                  Caribbean
# 16       Asia               Western Asia
# 17       Asia              Southern Asia
# 18   Americas                  Caribbean
# 19     Europe             Eastern Europe
# 20     Europe             Western Europe
# 21   Americas            Central America
# ...

# %%
df_world.pivot(index = 'country', columns = 'continent', values = 'sub_region')
# Out:
# continent                                                    Africa  \
# country
# Afghanistan                                                     NaN
# Albania                                                         NaN
# Algeria                                             Northern Africa
# American Samoa                                                  NaN
# Andorra                                                         NaN
# Angola                                                Middle Africa
# Anguilla                                                        NaN
# Antigua and Barbuda                                             NaN
# Argentina                                                       NaN
# Armenia                                                         NaN
# Aruba                                                           NaN
# Australia                                                       NaN
# Austria                                                         NaN
# ...

# %%
df_world.pivot(index = 'country', columns = 'continent', values = 'Unnamed: 4')
# Out:
# continent                                                  Africa  \
# country
# Afghanistan                                                   NaN
# Albania                                                       NaN
# Algeria                                                9,500,000
# American Samoa                                                NaN
# Andorra                                                       NaN
# Angola                                                54,000,000
# Anguilla                                                      NaN
# Antigua and Barbuda                                           NaN
# Argentina                                                     NaN
# Armenia                                                       NaN
# Aruba                                                         NaN
# Australia                                                     NaN
# Austria                                                       NaN
# ...

# %%
df_world.pivot(index ='country', columns =  ['continent','sub_region'], values = 'Unnamed: 4')
# Out:
# continent                                                      Asia  \
# sub_region                                            Southern Asia
# country
# Afghanistan                                              6,900,000
# Albania                                                         NaN
# Algeria                                                         NaN
# American Samoa                                                  NaN
# Andorra                                                         NaN
# Angola                                                          NaN
# Anguilla                                                        NaN
# Antigua and Barbuda                                             NaN
# Argentina                                                       NaN
# Armenia                                                         NaN
# Aruba                                                           NaN
# Australia                                                       NaN
# ...
